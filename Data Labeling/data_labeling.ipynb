# %%
# Block 1: Import libraries
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.calibration import CalibratedClassifierCV
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, clear_output
import joblib
import warnings
warnings.filterwarnings('ignore')

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
labeled_df = pd.read_csv('labeled_comments.csv', encoding="latin1")
labeled_df.head()
# Out:
#       video_id                author  \
# 0  g_fkq6WHcOs       @DesiCahaya-c7r
# 1  g_fkq6WHcOs  @CelineElviraNatalia
# 2  g_fkq6WHcOs        @borisdominggo
# 3  g_fkq6WHcOs         @noname-jb4rz
# 4  g_fkq6WHcOs            @SIAPA-e8b
#
#                                              comment  label
# 0                 Gambar kebaretnya boongan ternyata      0
# 1  Buat pemakai biasa sama saja iphone 16 promax,...      0
# 2                                Case poco&quot; ??      1
# 3  Kaum miFans dan kaum munafik iri dengki lg kum...      0
# 4                      Saya mah nunggu S26 Ultra aja      0

# %%
unlabeled_df = pd.read_csv('unlabeled_data.csv', encoding="latin1")
unlabeled_df.head()
# Out:
#       video_id                       author  \
# 0  O2xb1lVqUv4                     @rsa2147
# 1  O2xb1lVqUv4          @AntingWulanKuliner
# 2  O2xb1lVqUv4             @GateofNusantara
# 3  O2xb1lVqUv4  @sabilurrosyidtowilliam7163
# 4  O2xb1lVqUv4                    @nodengki
#
#                                              comment  Unnamed: 3
# 0  <a href="https://www.youtube.com/watch?v=O2xb1...         NaN
# 1  Ngapain beli iphon yg harga nya menjajah??????...         NaN
# 2  Hp China udh bagus2 dan tahan lama. Kamera jug...         NaN
# 3  Kalo Kualitasnya Semua Brand Android dari segi...         NaN
# 4  Brand HP paling worth it yg pernah sy pinang.<...         NaN

# %%
total = len(labeled_df) + len(unlabeled_df)
print(f"Labeled percentage: {len(labeled_df)/total*100:.1f}%")
print(f"Unlabeled percentage: {len(unlabeled_df)/total*100:.1f}%")

print(labeled_df['label'].value_counts().sort_index())
# Out:
# Labeled percentage: 26.4%
# Unlabeled percentage: 73.6%
# label
# 0    381
# 1    575
# 2    136
# Name: count, dtype: int64

# %%
X = labeled_df['comment'].fillna('')
y = labeled_df['label']

vectorizer = TfidfVectorizer(
  max_features=2000,
  ngram_range=(1, 2),
  min_df=2,
  max_df=0.95,
  stop_words=None
)

X_vec = vectorizer.fit_transform(X)

# Train SVM
base_svm = SVC(
  kernel='linear',
  probability=False,
  random_state=42,
  class_weight='balanced'
)

model = CalibratedClassifierCV(
  base_svm,
  method='sigmoid',
  cv=min(5, len(labeled_df))
)

model.fit(X_vec, y)

print("Initial SVM model trained successfully!")
print(f"Training data: {len(labeled_df)} comments")


train_predictions = model.predict(X_vec)
train_accuracy = (train_predictions == y).mean()
print(f"Training accuracy: {train_accuracy:.3f}")

print(classification_report(y, train_predictions))
# Out:
# Initial SVM model trained successfully!
# Training data: 1092 comments
# Training accuracy: 0.867
#               precision    recall  f1-score   support
#
#            0       0.85      0.94      0.89       381
#            1       0.88      0.92      0.90       575
#            2       0.91      0.44      0.59       136
#
#     accuracy                           0.87      1092
#    macro avg       0.88      0.77      0.79      1092
# weighted avg       0.87      0.87      0.86      1092

# %%
# Block 1: Split Unlabeled Data into 70% for Verification and 30% for Pseudo-labeling
def split_unlabeled_data(unlabeled_df, verification_ratio=0.7, pseudo_ratio=0.3):
    """
    Split unlabeled data into verification set (70%) and pseudo-labeling set (30%)
    """
    print("Splitting unlabeled data into verification and pseudo-labeling sets...")
    print(f"Total unlabeled data: {len(unlabeled_df)} comments")

    # Verify ratios sum to 1.0
    total_ratio = verification_ratio + pseudo_ratio
    if abs(total_ratio - 1.0) > 0.01:
        print(f"Warning: Ratios sum to {total_ratio}, normalizing to 1.0")
        verification_ratio = verification_ratio / total_ratio
        pseudo_ratio = pseudo_ratio / total_ratio

    # Calculate sizes
    verification_size = int(len(unlabeled_df) * verification_ratio)
    pseudo_size = len(unlabeled_df) - verification_size

    print(f"Verification set (Active Learning): {verification_size} comments ({verification_ratio*100}%)")
    print(f"Pseudo-labeling set: {pseudo_size} comments ({pseudo_ratio*100}%)")

    # Split the data
    verification_set = unlabeled_df.sample(n=verification_size, random_state=42)
    pseudo_set = unlabeled_df.drop(verification_set.index)

    # Verify the split
    print(f"\nSplit verification:")
    print(f"Verification set actual: {len(verification_set)}")
    print(f"Pseudo set actual: {len(pseudo_set)}")
    print(f"Total after split: {len(verification_set) + len(pseudo_set)}")

    # Save the splits
    verification_set.to_csv('unlabeled_verification.csv', index=False)
    pseudo_set.to_csv('unlabeled_pseudo.csv', index=False)

    print(f"\nSplit completed and saved:")
    print(f"  - unlabeled_verification.csv")
    print(f"  - unlabeled_pseudo.csv")

    return verification_set, pseudo_set

# Split the unlabeled data
verification_set, pseudo_set = split_unlabeled_data(unlabeled_df, verification_ratio=0.7, pseudo_ratio=0.3)
# Out:
# Splitting unlabeled data into verification and pseudo-labeling sets...
# Total unlabeled data: 3047 comments
# Verification set (Active Learning): 2132 comments (70.0%)
# Pseudo-labeling set: 915 comments (30.0%)
#
# Split verification:
# Verification set actual: 2132
# Pseudo set actual: 915
# Total after split: 3047
#
# Split completed and saved:
#   - unlabeled_verification.csv
#   - unlabeled_pseudo.csv

# %%
def get_sentiment_name(label):
    sentiment_mapping = {
        0: 'Negative',
        1: 'Neutral',
        2: 'Positive'
    }
    return sentiment_mapping.get(label, 'Unknown')

print("Testing get_sentiment_name function:")
print(f"0 -> {get_sentiment_name(0)}")
print(f"1 -> {get_sentiment_name(1)}")
print(f"2 -> {get_sentiment_name(2)}")
print(f"5 -> {get_sentiment_name(5)}")  # Should return 'Unknown'
# Out:
# Testing get_sentiment_name function:
# 0 -> Negative
# 1 -> Neutral
# 2 -> Positive
# 5 -> Unknown

# %%
# Block 2: Apply Model to 70% Verification Set
def apply_model_to_verification_set(model, vectorizer, verification_set):
    print("Applying model to 70% verification set...")
    print(f"Verification set size: {len(verification_set)} comments")

    # Prepare features
    X_verification = verification_set['comment'].fillna('')

    # Transform using the fitted vectorizer
    X_verification_vec = vectorizer.transform(X_verification)

    # Get predictions and probabilities
    predictions = model.predict(X_verification_vec)
    probabilities = model.predict_proba(X_verification_vec)
    max_probs = np.max(probabilities, axis=1)

    # Add predictions to dataframe
    predicted_verification = verification_set.copy()
    predicted_verification['model_label'] = predictions
    predicted_verification['model_confidence'] = max_probs
    predicted_verification['prob_negative'] = probabilities[:, 0]
    predicted_verification['prob_neutral'] = probabilities[:, 1]
    predicted_verification['prob_positive'] = probabilities[:, 2]

    # Categorize by confidence levels
    predicted_verification['confidence_level'] = pd.cut(
        max_probs,
        bins=[0, 0.6, 0.8, 0.9, 1.0],
        labels=['low', 'medium', 'high', 'very_high'],
        right=False
    )

    # Display prediction statistics
    print("\nModel Prediction Statistics for Verification Set:")
    print(f"Total predictions: {len(predicted_verification)}")

    print("\nConfidence Distribution:")
    conf_counts = predicted_verification['confidence_level'].value_counts()
    for level, count in conf_counts.items():
        percentage = count / len(predicted_verification) * 100
        print(f"  {level}: {count} comments ({percentage:.1f}%)")

    print("\nPredicted Label Distribution:")
    label_counts = predicted_verification['model_label'].value_counts().sort_index()
    for label, count in label_counts.items():
        sentiment = get_sentiment_name(label)
        percentage = count / len(predicted_verification) * 100
        print(f"  {sentiment}: {count} comments ({percentage:.1f}%)")

    # Save predictions for verification
    predicted_verification.to_csv('model_predictions_70percent_verification.csv', index=False)
    print(f"\n✓ Predictions saved to 'model_predictions_70percent_verification.csv'")

    return predicted_verification

# Apply model to 70% verification set
predicted_verification_df = apply_model_to_verification_set(model, vectorizer, verification_set)
# Out:
# Applying model to 70% verification set...
# Verification set size: 2132 comments
#
# Model Prediction Statistics for Verification Set:
# Total predictions: 2132
#
# Confidence Distribution:
#   low: 1096 comments (51.4%)
#   medium: 1036 comments (48.6%)
#   high: 0 comments (0.0%)
#   very_high: 0 comments (0.0%)
#
# Predicted Label Distribution:
#   Negative: 1010 comments (47.4%)
#   Neutral: 1024 comments (48.0%)
#   Positive: 98 comments (4.6%)
#
# ✓ Predictions saved to 'model_predictions_70percent_verification.csv'

# %%
# Block 3: Prepare Smart Verification Queue for 70% Data
def prepare_verification_queue(predicted_verification_df):
    print("Preparing smart verification queue for 70% verification set...")

    # Calculate uncertainty scores (1 - confidence)
    verification_queue = predicted_verification_df.copy()
    verification_queue['uncertainty'] = 1 - verification_queue['model_confidence']

    # Sort by uncertainty (most uncertain first)
    verification_queue = verification_queue.sort_values('uncertainty', ascending=False)

    print("Verification queue prepared with uncertainty sampling:")
    print(f"Total comments in queue: {len(verification_queue)}")
    print(f"Most uncertain confidence: {verification_queue['model_confidence'].iloc[0]:.3f}")
    print(f"Least uncertain confidence: {verification_queue['model_confidence'].iloc[-1]:.3f}")
    print(f"Average confidence: {verification_queue['model_confidence'].mean():.3f}")
    print(f"Average uncertainty: {verification_queue['uncertainty'].mean():.3f}")

    # Display queue composition
    print("\nQueue composition by confidence level:")
    queue_conf_counts = verification_queue['confidence_level'].value_counts()
    for level, count in queue_conf_counts.items():
        percentage = count / len(verification_queue) * 100
        print(f"  {level}: {count} comments ({percentage:.1f}%)")

    # Save the verification queue
    verification_queue.to_csv('manual_verification.csv', index=False)
    print(f"\n✓ Verification queue saved to 'manual_verification.csv'")

    return verification_queue

# Prepare verification queue
# verification_queue = prepare_verification_queue(predicted_verification_df)
verification_queue = pd.read_csv('manual_verification.csv')

# %%
# Block 4: Colab-Compatible Verification for 70% Data
def verify_data(verification_queue, batch_size=50, total_to_verify=None):
    print("Starting verification")

    if total_to_verify is None:
        total_to_verify = len(verification_queue)
    else:
        total_to_verify = min(total_to_verify, len(verification_queue))

    print(f"Total comments to verify: {total_to_verify}")
    print(f"Batch size: {batch_size}")

    # Create working copy
    verified_df = verification_queue.head(total_to_verify).copy()
    verified_df['human_label'] = np.nan
    verified_df['verified'] = False
    verified_df['verification_notes'] = ''

    total_verified = 0
    total_corrections = 0
    batch_number = 1



    # Process in batches
    for start_idx in range(0, len(verified_df), batch_size):
        end_idx = min(start_idx + batch_size, len(verified_df))
        current_batch = verified_df.iloc[start_idx:end_idx]

        print(f"\n{'='*60}")
        print(f"BATCH {batch_number} - Comments {start_idx + 1} to {end_idx}")
        print(f"Total target: {total_to_verify} comments")
        print(f"{'='*60}")

        batch_corrections = 0

        for i, (idx, row) in enumerate(current_batch.iterrows()):
            global_index = start_idx + i + 1

            print(f"\n" + "="*80)
            print(f"COMMENT {global_index}/{total_to_verify} (Batch {batch_number}.{i+1})")
            print("="*80)

            # Display comment information
            print(f"CONFIDENCE: {row['confidence_level']} ({row['model_confidence']:.3f})")
            print("-"*80)
            print(f"COMMENT:\n{row['comment']}")
            print("-"*80)

            # Display model prediction with probabilities
            print("MODEL PREDICTION:")
            print(f"  Label: {row['model_label']} ({get_sentiment_name(row['model_label'])})")
            print(f"  Confidence: {row['model_confidence']:.3f}")
            print(f"  Probabilities: Neg={row['prob_negative']:.3f}, Neu={row['prob_neutral']:.3f}, Pos={row['prob_positive']:.3f}")
            print("-"*80)

            # Verification options
            print("VERIFICATION OPTIONS:")
            print("0: Negative")
            print("1: Neutral")
            print("2: Positive")
            print("Enter: Accept model prediction")
            print("s: Skip this comment")
            print("="*80)

            while True:
                try:
                    choice = input("Enter your choice: ").strip().lower()

                    if choice == '':
                        # Accept model prediction
                        verified_df.at[idx, 'human_label'] = row['model_label']
                        verified_df.at[idx, 'verified'] = True
                        print("✓ Accepted model prediction")
                        break

                    elif choice in ['0', '1', '2']:
                        human_label = int(choice)
                        verified_df.at[idx, 'human_label'] = human_label
                        verified_df.at[idx, 'verified'] = True

                        if human_label != row['model_label']:
                            batch_corrections += 1
                            print(f"✓ Corrected from {row['model_label']} to {human_label}")
                        else:
                            print("✓ Confirmed model prediction")
                        break

                    elif choice == 's':
                        print("Skipped this comment")
                        break

                    else:
                        print("Invalid choice! Please enter 0, 1, 2, Enter, or 's'")

                except KeyboardInterrupt:
                    print("\nVerification interrupted by user")
                    return verified_df, total_verified, total_corrections
                except Exception as e:
                    print(f"Error: {e}. Please try again.")

        # Update totals after batch completion
        batch_verified = len(current_batch[current_batch['verified'] == True])
        total_verified += batch_verified
        total_corrections += batch_corrections

        overall_accuracy = 1 - (total_corrections / total_verified) if total_verified > 0 else 1.0

        print(f"\n✓ Batch {batch_number} completed!")
        print(f"  Verified in this batch: {batch_verified}")
        print(f"  Corrections in this batch: {batch_corrections}")
        print(f"  Batch accuracy: {1 - (batch_corrections/batch_verified) if batch_verified > 0 else 1.0:.1%}")
        print(f"  Total verified: {total_verified}/{total_to_verify}")
        print(f"  Overall accuracy: {overall_accuracy:.1%}")

        # Save progress after each batch
        verified_so_far = verified_df[verified_df['verified'] == True]
        if len(verified_so_far) > 0:
            verified_so_far.to_csv(f'verification_70percent_batch_{batch_number}.csv', index=False)
            print(f"  Progress saved: 'verification_70percent_batch_{batch_number}.csv'")

        batch_number += 1

        # Ask if user wants to continue
        if total_verified < total_to_verify:
            remaining = total_to_verify - total_verified
            cont = input(f"\n{remaining} comments remaining. Continue to next batch? (y/n): ").strip().lower()
            if cont != 'y':
                print("Verification paused by user.")
                break
        else:
            print(f"\n✓ Target of {total_to_verify} comments reached!")

    print(f"\n VERIFICATION COMPLETED!")
    print(f"Total verified: {total_verified}/{total_to_verify}")
    print(f"Total corrections: {total_corrections}")
    print(f"Final model accuracy: {1 - (total_corrections/total_verified) if total_verified > 0 else 1.0:.1%}")

    return verified_df, total_verified, total_corrections

# Start verification
print("Beginning verification of unlabeled data...")
verified_df, total_verified, total_corrections = verify_data(
    verification_queue,
    batch_size=50,
    total_to_verify=len(verification_queue)  # Verify all 70%
)
# Out:
# Streaming output truncated to the last 5000 lines.
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1487/2132 (Batch 30.37)
# ================================================================================
# CONFIDENCE: medium (0.670)
# --------------------------------------------------------------------------------
# COMMENT:
# Design poco, warna kayak infinix yg warna orange ini??<br>Paling aman warna hitam.<br>Atau putih mewah lumayan lah.<br>Tapiii pas dikasih case sangat hp china 2 jutaan??<br>Fix user 17 pro bakal ini bakal alergi sama case ??
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 0 (Negative)
#   Confidence: 0.670
#   Probabilities: Neg=0.670, Neu=0.152, Pos=0.178
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1488/2132 (Batch 30.38)
# ================================================================================
# CONFIDENCE: medium (0.670)
# --------------------------------------------------------------------------------
# COMMENT:
# jadi ragu beli 17 pro, mungkin yg 17 tp pilihan warna spt itu, ya sudah logis nya beli 16 warna pink
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 0 (Negative)
#   Confidence: 0.670
#   Probabilities: Neg=0.670, Neu=0.148, Pos=0.181
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1489/2132 (Batch 30.39)
# ================================================================================
# CONFIDENCE: medium (0.671)
# --------------------------------------------------------------------------------
# COMMENT:
# <a href="https://www.youtube.com/watch?v=9-poYwCZxDQ&amp;t=1239">20:39</a> itu Oza Rangkuti bang, nama tiktodnya podcast kesel aje ?? emang konten andalannya kaya gt &quot;lu tau orang2 yang beli iPhone 17 duluan, ini kira2 yang pengen mereka denger&quot; ??
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.671
#   Probabilities: Neg=0.251, Neu=0.671, Pos=0.078
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1490/2132 (Batch 30.40)
# ================================================================================
# CONFIDENCE: medium (0.671)
# --------------------------------------------------------------------------------
# COMMENT:
# david : kalo ingin lihat lgsg review 17 pro lgsg di timestamp manfaatkan fitur<br>??? : oh tidak bisa (kami nonton anda itu menyenangkan dan ditunggu)
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.671
#   Probabilities: Neg=0.257, Neu=0.671, Pos=0.072
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1491/2132 (Batch 30.41)
# ================================================================================
# CONFIDENCE: medium (0.671)
# --------------------------------------------------------------------------------
# COMMENT:
# Hp ketinggalan jaman baru keluar??
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.671
#   Probabilities: Neg=0.253, Neu=0.671, Pos=0.076
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1492/2132 (Batch 30.42)
# ================================================================================
# CONFIDENCE: medium (0.671)
# --------------------------------------------------------------------------------
# COMMENT:
# iphone 16 pro desain kamera dan warna nya kayak realme c67 4g 2023
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 0 (Negative)
#   Confidence: 0.671
#   Probabilities: Neg=0.671, Neu=0.150, Pos=0.179
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1493/2132 (Batch 30.43)
# ================================================================================
# CONFIDENCE: medium (0.671)
# --------------------------------------------------------------------------------
# COMMENT:
# S24 dh nyaman bgt!!
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.671
#   Probabilities: Neg=0.253, Neu=0.671, Pos=0.076
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1494/2132 (Batch 30.44)
# ================================================================================
# CONFIDENCE: medium (0.671)
# --------------------------------------------------------------------------------
# COMMENT:
# iPhone 17 kaya Poco gak sih ??
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 0 (Negative)
#   Confidence: 0.671
#   Probabilities: Neg=0.671, Neu=0.150, Pos=0.179
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1495/2132 (Batch 30.45)
# ================================================================================
# CONFIDENCE: medium (0.671)
# --------------------------------------------------------------------------------
# COMMENT:
# Bener bang <a href="https://www.youtube.com/watch?v=9-poYwCZxDQ&amp;t=831">13:51</a> jd lebih fokus lgi cuma buat pilih app , lbih baik yg ada warna nya aja ??
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.671
#   Probabilities: Neg=0.255, Neu=0.671, Pos=0.074
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1496/2132 (Batch 30.46)
# ================================================================================
# CONFIDENCE: medium (0.671)
# --------------------------------------------------------------------------------
# COMMENT:
# Sepertinya 17pro better di kamera depan atau selfie nya dibanding seri 16pro
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.671
#   Probabilities: Neg=0.253, Neu=0.671, Pos=0.075
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice: 2
# ✓ Corrected from 1 to 2
#
# ================================================================================
# COMMENT 1497/2132 (Batch 30.47)
# ================================================================================
# CONFIDENCE: medium (0.671)
# --------------------------------------------------------------------------------
# COMMENT:
# Kalau siomay gua malah lbh suka kalau dia ga upgrade os soalnya setiap update malah merusak yg lain. Cthnya miui 14 yg terakhir tuh ngilangin fitur fast/turbo charging mesti diakalin pake software lain, iklan jd auto balik setiap 30-90 hari walaupun udah dimatiin ga bisa permanen lg, dll. Kampret emang siomay, ngupdate bukan tambah bagus malah tambah ancur. Hyper os malah jd hyper bug. Kalau dulu msh okelah dimaklumi krn murah, tp kalau skrng ogah banget krn udah mahal.??
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 0 (Negative)
#   Confidence: 0.671
#   Probabilities: Neg=0.671, Neu=0.153, Pos=0.175
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice: 1
# ✓ Corrected from 0 to 1
#
# ================================================================================
# COMMENT 1498/2132 (Batch 30.48)
# ================================================================================
# CONFIDENCE: medium (0.671)
# --------------------------------------------------------------------------------
# COMMENT:
# <a href="https://www.youtube.com/watch?v=9-poYwCZxDQ&amp;t=1260">21:00</a> &quot;uh beda ya&quot; wkwk,<br>gpp bang bilang aja desainnya kureng, kita juga setuju kok ??
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.671
#   Probabilities: Neg=0.253, Neu=0.671, Pos=0.076
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice: 0
# ✓ Corrected from 1 to 0
#
# ================================================================================
# COMMENT 1499/2132 (Batch 30.49)
# ================================================================================
# CONFIDENCE: medium (0.671)
# --------------------------------------------------------------------------------
# COMMENT:
# harus ada beberapa orang baru bisa auto rotasinya
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.671
#   Probabilities: Neg=0.254, Neu=0.671, Pos=0.074
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1500/2132 (Batch 30.50)
# ================================================================================
# CONFIDENCE: medium (0.672)
# --------------------------------------------------------------------------------
# COMMENT:
# nggak butuh ai dan lensa tele tapi butuh gengsi yahsudah apple aja,,, lebih stabil
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 0 (Negative)
#   Confidence: 0.672
#   Probabilities: Neg=0.672, Neu=0.154, Pos=0.174
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice: 2
# ✓ Corrected from 0 to 2
#
# ✓ Batch 30 completed!
#   Verified in this batch: 50
#   Corrections in this batch: 11
#   Batch accuracy: 78.0%
#   Total verified: 1500/2132
#   Overall accuracy: 64.3%
#   Progress saved: 'verification_70percent_batch_30.csv'
#
# 632 comments remaining. Continue to next batch? (y/n): y
#
# ============================================================
# BATCH 31 - Comments 1501 to 1550
# Total target: 2132 comments
# ============================================================
#
# ================================================================================
# COMMENT 1501/2132 (Batch 31.1)
# ================================================================================
# CONFIDENCE: medium (0.672)
# --------------------------------------------------------------------------------
# COMMENT:
# iPoco M6 Pro terkeren yang pernah ada  ??
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.672
#   Probabilities: Neg=0.254, Neu=0.672, Pos=0.074
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice: 0
# ✓ Corrected from 1 to 0
#
# ================================================================================
# COMMENT 1502/2132 (Batch 31.2)
# ================================================================================
# CONFIDENCE: medium (0.672)
# --------------------------------------------------------------------------------
# COMMENT:
# 17 ini tanda awal kehancuran apple, minim inovasi tapi harga mahal
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 0 (Negative)
#   Confidence: 0.672
#   Probabilities: Neg=0.672, Neu=0.150, Pos=0.177
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1503/2132 (Batch 31.3)
# ================================================================================
# CONFIDENCE: medium (0.673)
# --------------------------------------------------------------------------------
# COMMENT:
# Syarat biar bisa selfi landskap 3-4 orang lebih bang david baru akan aktif fiturnya, klo cuman ada satu orang di sebelah fiturnya gk bakalan aktif
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.673
#   Probabilities: Neg=0.250, Neu=0.673, Pos=0.078
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1504/2132 (Batch 31.4)
# ================================================================================
# CONFIDENCE: medium (0.673)
# --------------------------------------------------------------------------------
# COMMENT:
# xiaomi 17 pro lagi vid
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.673
#   Probabilities: Neg=0.255, Neu=0.673, Pos=0.072
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1505/2132 (Batch 31.5)
# ================================================================================
# CONFIDENCE: medium (0.673)
# --------------------------------------------------------------------------------
# COMMENT:
# yg nonton pake iponk XR mana suaranya???
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.673
#   Probabilities: Neg=0.254, Neu=0.673, Pos=0.073
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1506/2132 (Batch 31.6)
# ================================================================================
# CONFIDENCE: medium (0.673)
# --------------------------------------------------------------------------------
# COMMENT:
# <a href="https://www.youtube.com/watch?v=9-poYwCZxDQ&amp;t=1307">21:47</a> kok 16pro digemgam tangan kanan kok langsung remuk ? ??????
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.673
#   Probabilities: Neg=0.253, Neu=0.673, Pos=0.074
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1507/2132 (Batch 31.7)
# ================================================================================
# CONFIDENCE: medium (0.673)
# --------------------------------------------------------------------------------
# COMMENT:
# cung yg nonton video ini masih pakai 14 pro??
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.673
#   Probabilities: Neg=0.253, Neu=0.673, Pos=0.074
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1508/2132 (Batch 31.8)
# ================================================================================
# CONFIDENCE: medium (0.673)
# --------------------------------------------------------------------------------
# COMMENT:
# bang coba 15 16 17 test camera mana yg lebih baik  ??
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.673
#   Probabilities: Neg=0.252, Neu=0.673, Pos=0.075
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1509/2132 (Batch 31.9)
# ================================================================================
# CONFIDENCE: medium (0.673)
# --------------------------------------------------------------------------------
# COMMENT:
# <a href="https://www.youtube.com/watch?v=9-poYwCZxDQ&amp;t=1257">20:57</a> Poco x6 itu pakai garskin aipon
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.673
#   Probabilities: Neg=0.252, Neu=0.673, Pos=0.075
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice: 0
# ✓ Corrected from 1 to 0
#
# ================================================================================
# COMMENT 1510/2132 (Batch 31.10)
# ================================================================================
# CONFIDENCE: medium (0.673)
# --------------------------------------------------------------------------------
# COMMENT:
# Harus banyak org bg bru bisa auto landscape
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.673
#   Probabilities: Neg=0.253, Neu=0.673, Pos=0.074
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1511/2132 (Batch 31.11)
# ================================================================================
# CONFIDENCE: medium (0.674)
# --------------------------------------------------------------------------------
# COMMENT:
# Sebenarnya ini cuma unboxing, reviewnya jg blm detail. Masalah warna, kalo dr awal ga suka ya hrsnya ga dibeli warna itu, cuma kan utk kepentingan engagement konten, ya di beli lah warna yg wow itu. Netizen santai aja ??
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 0 (Negative)
#   Confidence: 0.674
#   Probabilities: Neg=0.674, Neu=0.151, Pos=0.176
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1512/2132 (Batch 31.12)
# ================================================================================
# CONFIDENCE: medium (0.674)
# --------------------------------------------------------------------------------
# COMMENT:
# Xiaomi 17 por max dong
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.674
#   Probabilities: Neg=0.254, Neu=0.674, Pos=0.072
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1513/2132 (Batch 31.13)
# ================================================================================
# CONFIDENCE: medium (0.674)
# --------------------------------------------------------------------------------
# COMMENT:
# paling bener emang beli yg base model atau langsung ke pro series sekalian ??
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.674
#   Probabilities: Neg=0.245, Neu=0.674, Pos=0.082
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1514/2132 (Batch 31.14)
# ================================================================================
# CONFIDENCE: medium (0.674)
# --------------------------------------------------------------------------------
# COMMENT:
# Nonton ini pake iPhone 6s jadul??
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.674
#   Probabilities: Neg=0.247, Neu=0.674, Pos=0.079
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1515/2132 (Batch 31.15)
# ================================================================================
# CONFIDENCE: medium (0.674)
# --------------------------------------------------------------------------------
# COMMENT:
# banggg unboxing pixel 10
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.674
#   Probabilities: Neg=0.250, Neu=0.674, Pos=0.076
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1516/2132 (Batch 31.16)
# ================================================================================
# CONFIDENCE: medium (0.674)
# --------------------------------------------------------------------------------
# COMMENT:
# Bang tips buat yang mau beli hp iphone di online shop dong
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.674
#   Probabilities: Neg=0.251, Neu=0.674, Pos=0.075
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1517/2132 (Batch 31.17)
# ================================================================================
# CONFIDENCE: medium (0.674)
# --------------------------------------------------------------------------------
# COMMENT:
# <a href="https://www.youtube.com/watch?v=9-poYwCZxDQ&amp;t=185">3:05</a> hijau miskin ga tuhh :(
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.674
#   Probabilities: Neg=0.250, Neu=0.674, Pos=0.076
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1518/2132 (Batch 31.18)
# ================================================================================
# CONFIDENCE: medium (0.674)
# --------------------------------------------------------------------------------
# COMMENT:
# Belum move on..CLBK??
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.674
#   Probabilities: Neg=0.249, Neu=0.674, Pos=0.076
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1519/2132 (Batch 31.19)
# ================================================================================
# CONFIDENCE: medium (0.674)
# --------------------------------------------------------------------------------
# COMMENT:
# Baang hp andoid yang anti lelet doong yang harganya atas 1,5
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.674
#   Probabilities: Neg=0.250, Neu=0.674, Pos=0.076
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1520/2132 (Batch 31.20)
# ================================================================================
# CONFIDENCE: medium (0.674)
# --------------------------------------------------------------------------------
# COMMENT:
# Kalo kamera nya di compare  sama Nokia 808  pureview siapa yang menang ??
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.674
#   Probabilities: Neg=0.251, Neu=0.674, Pos=0.074
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1521/2132 (Batch 31.21)
# ================================================================================
# CONFIDENCE: medium (0.675)
# --------------------------------------------------------------------------------
# COMMENT:
# <a href="https://www.youtube.com/watch?v=9-poYwCZxDQ&amp;t=1040">17:20</a> kayaknya itu harus lebih dari 2 orang bang , soalnya kemarin liat tiktokera nyoba auto rotate nya itu 5 orang an
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.675
#   Probabilities: Neg=0.251, Neu=0.675, Pos=0.074
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1522/2132 (Batch 31.22)
# ================================================================================
# CONFIDENCE: medium (0.675)
# --------------------------------------------------------------------------------
# COMMENT:
# <a href="https://www.youtube.com/watch?v=9-poYwCZxDQ&amp;t=1503">25:03</a> kayak Poco ??
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.675
#   Probabilities: Neg=0.251, Neu=0.675, Pos=0.074
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1523/2132 (Batch 31.23)
# ================================================================================
# CONFIDENCE: medium (0.675)
# --------------------------------------------------------------------------------
# COMMENT:
# <a href="https://www.youtube.com/watch?v=O2xb1lVqUv4&amp;t=635">10:35</a> saat itu aq jd pengguna Huawei P30 dan jg Matte 20P, dan saya sangat PUAS...
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.675
#   Probabilities: Neg=0.249, Neu=0.675, Pos=0.076
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1524/2132 (Batch 31.24)
# ================================================================================
# CONFIDENCE: medium (0.675)
# --------------------------------------------------------------------------------
# COMMENT:
# Xiaomi kah itu wkwkwk ??????
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.675
#   Probabilities: Neg=0.252, Neu=0.675, Pos=0.073
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1525/2132 (Batch 31.25)
# ================================================================================
# CONFIDENCE: medium (0.675)
# --------------------------------------------------------------------------------
# COMMENT:
# Siapa yg nonton pke Redmi Note 10 Pro ? ????
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.675
#   Probabilities: Neg=0.248, Neu=0.675, Pos=0.077
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1526/2132 (Batch 31.26)
# ================================================================================
# CONFIDENCE: medium (0.676)
# --------------------------------------------------------------------------------
# COMMENT:
# masih di 12... ????
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.676
#   Probabilities: Neg=0.250, Neu=0.676, Pos=0.074
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1527/2132 (Batch 31.27)
# ================================================================================
# CONFIDENCE: medium (0.676)
# --------------------------------------------------------------------------------
# COMMENT:
# Infonya setelah peluncuran iPhone 17 series ini saham iPhone turun &amp; investor di apple mengeluhkan minimnya inovasi. tapi harga tetap naik
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 0 (Negative)
#   Confidence: 0.676
#   Probabilities: Neg=0.676, Neu=0.151, Pos=0.173
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1528/2132 (Batch 31.28)
# ================================================================================
# CONFIDENCE: medium (0.676)
# --------------------------------------------------------------------------------
# COMMENT:
# Menyaksikan unboxing ip 17 pake ip 6s ??
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.676
#   Probabilities: Neg=0.166, Neu=0.676, Pos=0.158
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1529/2132 (Batch 31.29)
# ================================================================================
# CONFIDENCE: medium (0.676)
# --------------------------------------------------------------------------------
# COMMENT:
# Ini semua HP yang udah di review sama ka david pada dikemanain yaa?? (Tanya dengan nada lembut, selembut hembusan buat kaca)
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.676
#   Probabilities: Neg=0.185, Neu=0.676, Pos=0.139
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1530/2132 (Batch 31.30)
# ================================================================================
# CONFIDENCE: medium (0.676)
# --------------------------------------------------------------------------------
# COMMENT:
# Nonton smbil nongkrong ngeden??
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.676
#   Probabilities: Neg=0.250, Neu=0.676, Pos=0.074
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1531/2132 (Batch 31.31)
# ================================================================================
# CONFIDENCE: medium (0.676)
# --------------------------------------------------------------------------------
# COMMENT:
# ayolahhh dia belum selesei ngomong udah diganti aja ke topik laen, lagi seruuu bahas yang satu eh dibelokin ke yang laenn, jadinya kan gimana gitu
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.676
#   Probabilities: Neg=0.250, Neu=0.676, Pos=0.074
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1532/2132 (Batch 31.32)
# ================================================================================
# CONFIDENCE: medium (0.676)
# --------------------------------------------------------------------------------
# COMMENT:
# Besok beli xiomay 17pro max yg asli,
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.676
#   Probabilities: Neg=0.169, Neu=0.676, Pos=0.155
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1533/2132 (Batch 31.33)
# ================================================================================
# CONFIDENCE: medium (0.676)
# --------------------------------------------------------------------------------
# COMMENT:
# Investor sangat kecewa
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.676
#   Probabilities: Neg=0.246, Neu=0.676, Pos=0.077
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice: 0
# ✓ Corrected from 1 to 0
#
# ================================================================================
# COMMENT 1534/2132 (Batch 31.34)
# ================================================================================
# CONFIDENCE: medium (0.676)
# --------------------------------------------------------------------------------
# COMMENT:
# <a href="https://www.youtube.com/watch?v=9-poYwCZxDQ&amp;t=836">13:56</a> Setuju banget, karna kalo pake yang warna gelas tadi kayak agak lambat ini mata buat tau mana aplikasi yang biasa di pake (mungkin karna belum terbiasa juga)
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.676
#   Probabilities: Neg=0.248, Neu=0.676, Pos=0.076
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1535/2132 (Batch 31.35)
# ================================================================================
# CONFIDENCE: medium (0.677)
# --------------------------------------------------------------------------------
# COMMENT:
# Tetap nonton review ip17 Meskipun pake android samsung s24 ultra
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.677
#   Probabilities: Neg=0.250, Neu=0.677, Pos=0.074
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1536/2132 (Batch 31.36)
# ================================================================================
# CONFIDENCE: medium (0.677)
# --------------------------------------------------------------------------------
# COMMENT:
# Lebih bagus 16 kameranya ????
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 0 (Negative)
#   Confidence: 0.677
#   Probabilities: Neg=0.677, Neu=0.150, Pos=0.174
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1537/2132 (Batch 31.37)
# ================================================================================
# CONFIDENCE: medium (0.677)
# --------------------------------------------------------------------------------
# COMMENT:
# Review Motorola Moto Pad 60 pro....makasih bang David
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.677
#   Probabilities: Neg=0.086, Neu=0.677, Pos=0.238
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1538/2132 (Batch 31.38)
# ================================================================================
# CONFIDENCE: medium (0.677)
# --------------------------------------------------------------------------------
# COMMENT:
# Saya gk pernah tergantung oleh ipod,iphone atau,imac??..menurut saya semua sama saja sebelum bisa menciptakan hp bisa terbang,hp bisa mencuci baju,hp bisa membuat tubuh menghilang.
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.677
#   Probabilities: Neg=0.241, Neu=0.677, Pos=0.083
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ...
#   Label: 1 (Neutral)
#   Confidence: 0.685
#   Probabilities: Neg=0.236, Neu=0.685, Pos=0.080
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1684/2132 (Batch 34.34)
# ================================================================================
# CONFIDENCE: medium (0.685)
# --------------------------------------------------------------------------------
# COMMENT:
# Bang Hp sebelumny gk ada niat d jual emangny.?
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.685
#   Probabilities: Neg=0.238, Neu=0.685, Pos=0.077
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1685/2132 (Batch 34.35)
# ================================================================================
# CONFIDENCE: medium (0.685)
# --------------------------------------------------------------------------------
# COMMENT:
# Sangat worth it gak bg buat yg gaji nya 2,5 juta sebulan ??
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.685
#   Probabilities: Neg=0.237, Neu=0.685, Pos=0.077
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1686/2132 (Batch 34.36)
# ================================================================================
# CONFIDENCE: medium (0.685)
# --------------------------------------------------------------------------------
# COMMENT:
# Nonton <a href="https://www.youtube.com/watch?v=O2xb1lVqUv4&amp;t=2774">46:14</a> menit<br>Terasa sangat cepat ??
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.685
#   Probabilities: Neg=0.240, Neu=0.685, Pos=0.075
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1687/2132 (Batch 34.37)
# ================================================================================
# CONFIDENCE: medium (0.685)
# --------------------------------------------------------------------------------
# COMMENT:
# Kayaknya itu karena filter warna fotonya bg, karena di 16 pro itu kayaknya yang default, kalo yang 17 pro itu kayaknya pake filter yang amber atau golden atau apa gitu makanya keliatan beda detailnya wkwkwk cmiiw
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.685
#   Probabilities: Neg=0.240, Neu=0.685, Pos=0.075
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1688/2132 (Batch 34.38)
# ================================================================================
# CONFIDENCE: medium (0.685)
# --------------------------------------------------------------------------------
# COMMENT:
# 120 hz 13 - 18 juta tergantung storage. Mi berapa 3 juta 144 hz  andro udah 144 hz wkwkwkwk
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.685
#   Probabilities: Neg=0.237, Neu=0.685, Pos=0.078
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1689/2132 (Batch 34.39)
# ================================================================================
# CONFIDENCE: medium (0.686)
# --------------------------------------------------------------------------------
# COMMENT:
# yang lain doa biar bisa dapetin ni hp, klo sy doa biar ga nganggur lagi
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.686
#   Probabilities: Neg=0.234, Neu=0.686, Pos=0.080
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1690/2132 (Batch 34.40)
# ================================================================================
# CONFIDENCE: medium (0.686)
# --------------------------------------------------------------------------------
# COMMENT:
# <a href="https://www.youtube.com/watch?v=9-poYwCZxDQ&amp;t=755">12:35</a> &quot;monokrom njirrr&quot;??
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.686
#   Probabilities: Neg=0.236, Neu=0.686, Pos=0.078
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice: 0
# ✓ Corrected from 1 to 0
#
# ================================================================================
# COMMENT 1691/2132 (Batch 34.41)
# ================================================================================
# CONFIDENCE: medium (0.686)
# --------------------------------------------------------------------------------
# COMMENT:
# Mirip hijaunya xiomi 15
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.686
#   Probabilities: Neg=0.237, Neu=0.686, Pos=0.077
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1692/2132 (Batch 34.42)
# ================================================================================
# CONFIDENCE: medium (0.686)
# --------------------------------------------------------------------------------
# COMMENT:
# nonton masih pake hp vivo y91 varian ram 2/32??
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.686
#   Probabilities: Neg=0.240, Neu=0.686, Pos=0.074
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1693/2132 (Batch 34.43)
# ================================================================================
# CONFIDENCE: medium (0.686)
# --------------------------------------------------------------------------------
# COMMENT:
# Bang David minta recom RAM 6 dibawah 1,5 &amp; toko shope yg terpercaya terimakasih ????
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.686
#   Probabilities: Neg=0.235, Neu=0.686, Pos=0.079
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1694/2132 (Batch 34.44)
# ================================================================================
# CONFIDENCE: medium (0.686)
# --------------------------------------------------------------------------------
# COMMENT:
# Beliau lagi???
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.686
#   Probabilities: Neg=0.233, Neu=0.686, Pos=0.081
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1695/2132 (Batch 34.45)
# ================================================================================
# CONFIDENCE: medium (0.686)
# --------------------------------------------------------------------------------
# COMMENT:
# Bang koreksi <a href="https://www.youtube.com/watch?v=9-poYwCZxDQ&amp;t=183">3:03</a> jangan pakai ijo miskin, apalagi abang sebut rumah rumah, netijen kita sekarang kritis bang??
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.686
#   Probabilities: Neg=0.239, Neu=0.686, Pos=0.075
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1696/2132 (Batch 34.46)
# ================================================================================
# CONFIDENCE: medium (0.686)
# --------------------------------------------------------------------------------
# COMMENT:
# buset ternyata om ded didenger langsung produsen
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.686
#   Probabilities: Neg=0.236, Neu=0.686, Pos=0.077
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1697/2132 (Batch 34.47)
# ================================================================================
# CONFIDENCE: medium (0.687)
# --------------------------------------------------------------------------------
# COMMENT:
# halo david di sini
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.687
#   Probabilities: Neg=0.236, Neu=0.687, Pos=0.077
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1698/2132 (Batch 34.48)
# ================================================================================
# CONFIDENCE: medium (0.687)
# --------------------------------------------------------------------------------
# COMMENT:
# Lagi nunggu Xiaomi 17 pro ??
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.687
#   Probabilities: Neg=0.240, Neu=0.687, Pos=0.073
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1699/2132 (Batch 34.49)
# ================================================================================
# CONFIDENCE: medium (0.687)
# --------------------------------------------------------------------------------
# COMMENT:
# Tanggung nanti nunggu iPhone 20 pro dikit lagi 3 lagi wkwkwkw
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.687
#   Probabilities: Neg=0.146, Neu=0.687, Pos=0.166
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 1700/2132 (Batch 34.50)
# ================================================================================
# CONFIDENCE: medium (0.687)
# --------------------------------------------------------------------------------
# COMMENT:
# Ini yang ditunggu²
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.687
#   Probabilities: Neg=0.231, Neu=0.687, Pos=0.081
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice: 2
# ✓ Corrected from 1 to 2
#
# ✓ Batch 34 completed!
#   Verified in this batch: 50
#   Corrections in this batch: 8
#   Batch accuracy: 84.0%
#   Total verified: 1700/2132
#   Overall accuracy: 66.7%
#   Progress saved: 'verification_70percent_batch_34.csv'
#
# 432 comments remaining. Continue to next batch? (y/n): n
# Verification paused by user.
#
#  VERIFICATION COMPLETED!
# Total verified: 1700/2132
# Total corrections: 566
# Final model accuracy: 66.7%

# %%
# Block 4: Colab-Compatible Verification for 70% Data WITH RESUME FUNCTIONALITY
def verify_data(verification_queue, batch_size=50, total_to_verify=None, resume_from_batch=None):
    print("Starting verification")

    # === NEW: RESUME FUNCTIONALITY ===
    if resume_from_batch is not None:
        print(f"🔄 RESUMING FROM BATCH {resume_from_batch}")
        # Try to load previous progress
        try:
            previous_file = f'verification_70percent_batch_{resume_from_batch-1}.csv'
            previous_progress = pd.read_csv(previous_file)
            print(f"📁 Loaded previous progress: {len(previous_progress)} verified comments")

            # Get already verified comments
            verified_comments = set(previous_progress['comment'].astype(str))

            # Filter out already verified comments
            verification_queue = verification_queue[
                ~verification_queue['comment'].astype(str).isin(verified_comments)
            ]
            print(f"📊 Remaining comments to verify: {len(verification_queue)}")

        except FileNotFoundError:
            print(f"❌ Could not find batch {resume_from_batch-1} file. Starting from beginning.")
    # === END NEW ===

    if total_to_verify is None:
        total_to_verify = len(verification_queue)
    else:
        total_to_verify = min(total_to_verify, len(verification_queue))

    print(f"Total comments to verify: {total_to_verify}")
    print(f"Batch size: {batch_size}")

    # Create working copy
    verified_df = verification_queue.head(total_to_verify).copy()
    verified_df['human_label'] = np.nan
    verified_df['verified'] = False
    verified_df['verification_notes'] = ''

    total_verified = 0
    total_corrections = 0

    # === NEW: SET STARTING BATCH NUMBER ===
    if resume_from_batch is not None:
        batch_number = resume_from_batch
        print(f"🎯 Starting from batch {batch_number}")
    else:
        batch_number = 1
    # === END NEW ===

    # Process in batches
    for start_idx in range(0, len(verified_df), batch_size):
        end_idx = min(start_idx + batch_size, len(verified_df))
        current_batch = verified_df.iloc[start_idx:end_idx]

        print(f"\n{'='*60}")
        print(f"BATCH {batch_number} - Comments {start_idx + 1} to {end_idx}")
        print(f"Total target: {total_to_verify} comments")
        print(f"{'='*60}")

        batch_corrections = 0

        for i, (idx, row) in enumerate(current_batch.iterrows()):
            global_index = start_idx + i + 1

            print(f"\n" + "="*80)
            print(f"COMMENT {global_index}/{total_to_verify} (Batch {batch_number}.{i+1})")
            print("="*80)

            # Display comment information
            print(f"CONFIDENCE: {row['confidence_level']} ({row['model_confidence']:.3f})")
            print("-"*80)
            print(f"COMMENT:\n{row['comment']}")
            print("-"*80)

            # Display model prediction with probabilities
            print("MODEL PREDICTION:")
            print(f"  Label: {row['model_label']} ({get_sentiment_name(row['model_label'])})")
            print(f"  Confidence: {row['model_confidence']:.3f}")
            print(f"  Probabilities: Neg={row['prob_negative']:.3f}, Neu={row['prob_neutral']:.3f}, Pos={row['prob_positive']:.3f}")
            print("-"*80)

            # Verification options
            print("VERIFICATION OPTIONS:")
            print("0: Negative")
            print("1: Neutral")
            print("2: Positive")
            print("Enter: Accept model prediction")
            print("s: Skip this comment")
            print("="*80)

            while True:
                try:
                    choice = input("Enter your choice: ").strip().lower()

                    if choice == '':
                        # Accept model prediction
                        verified_df.at[idx, 'human_label'] = row['model_label']
                        verified_df.at[idx, 'verified'] = True
                        print("✓ Accepted model prediction")
                        break

                    elif choice in ['0', '1', '2']:
                        human_label = int(choice)
                        verified_df.at[idx, 'human_label'] = human_label
                        verified_df.at[idx, 'verified'] = True

                        if human_label != row['model_label']:
                            batch_corrections += 1
                            print(f"✓ Corrected from {row['model_label']} to {human_label}")
                        else:
                            print("✓ Confirmed model prediction")
                        break

                    elif choice == 's':
                        print("Skipped this comment")
                        break

                    else:
                        print("Invalid choice! Please enter 0, 1, 2, Enter, or 's'")

                except KeyboardInterrupt:
                    print("\nVerification interrupted by user")
                    return verified_df, total_verified, total_corrections
                except Exception as e:
                    print(f"Error: {e}. Please try again.")

        # Update totals after batch completion
        batch_verified = len(current_batch[current_batch['verified'] == True])
        total_verified += batch_verified
        total_corrections += batch_corrections

        overall_accuracy = 1 - (total_corrections / total_verified) if total_verified > 0 else 1.0

        print(f"\n✓ Batch {batch_number} completed!")
        print(f"  Verified in this batch: {batch_verified}")
        print(f"  Corrections in this batch: {batch_corrections}")
        print(f"  Batch accuracy: {1 - (batch_corrections/batch_verified) if batch_verified > 0 else 1.0:.1%}")
        print(f"  Total verified: {total_verified}/{total_to_verify}")
        print(f"  Overall accuracy: {overall_accuracy:.1%}")

        # Save progress after each batch
        verified_so_far = verified_df[verified_df['verified'] == True]
        if len(verified_so_far) > 0:
            verified_so_far.to_csv(f'verification_70percent_batch_{batch_number}.csv', index=False)
            print(f"  Progress saved: 'verification_70percent_batch_{batch_number}.csv'")

        batch_number += 1

        # Ask if user wants to continue
        if total_verified < total_to_verify:
            remaining = total_to_verify - total_verified
            cont = input(f"\n{remaining} comments remaining. Continue to next batch? (y/n): ").strip().lower()
            if cont != 'y':
                print("Verification paused by user.")
                break
        else:
            print(f"\n✓ Target of {total_to_verify} comments reached!")

    print(f"\n VERIFICATION COMPLETED!")
    print(f"Total verified: {total_verified}/{total_to_verify}")
    print(f"Total corrections: {total_corrections}")
    print(f"Final model accuracy: {1 - (total_corrections/total_verified) if total_verified > 0 else 1.0:.1%}")

    return verified_df, total_verified, total_corrections

# === NEW: FUNCTION TO CHECK PROGRESS ===
def check_verification_progress():
    """Check what batches have been completed and suggest where to resume"""
    import glob
    batch_files = glob.glob('verification_70percent_batch_*.csv')

    if not batch_files:
        print("❌ No verification progress found. Start from batch 1.")
        return None

    batch_numbers = []
    for file in batch_files:
        try:
            batch_num = int(file.split('_')[-1].split('.')[0])
            batch_numbers.append(batch_num)
        except:
            continue

    if batch_numbers:
        latest_batch = max(batch_numbers)
        print(f"📊 Found progress up to batch {latest_batch}")
        print(f"💡 To resume, use: resume_from_batch={latest_batch + 1}")
        return latest_batch + 1
    else:
        print("❌ No valid batch files found.")
        return None

# === CHECK PROGRESS FIRST ===
print("Checking existing verification progress...")
next_batch = check_verification_progress()

if next_batch is not None:
    # RESUME from where you left off
    print(f"\n🔄 RESUMING VERIFICATION FROM BATCH {next_batch}")
    verified_df, total_verified, total_corrections = verify_data(
        verification_queue,
        batch_size=50,
        total_to_verify=len(verification_queue),
        resume_from_batch=next_batch  # === NEW PARAMETER ===
    )
else:
    # START FRESH
    print("\n🚀 STARTING NEW VERIFICATION FROM BATCH 1")
    verified_df, total_verified, total_corrections = verify_data(
        verification_queue,
        batch_size=50,
        total_to_verify=len(verification_queue)
    )
# Out:
# Streaming output truncated to the last 5000 lines.
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 219/432 (Batch 39.19)
# ================================================================================
# CONFIDENCE: medium (0.712)
# --------------------------------------------------------------------------------
# COMMENT:
# .IP 17 base model Terbaik selanjutnya kah setelah IP 13 base model
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.712
#   Probabilities: Neg=0.153, Neu=0.712, Pos=0.135
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 220/432 (Batch 39.20)
# ================================================================================
# CONFIDENCE: medium (0.712)
# --------------------------------------------------------------------------------
# COMMENT:
# bahkan, bang david tidak mengetahui spek hpnya sendiri??
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.712
#   Probabilities: Neg=0.162, Neu=0.712, Pos=0.126
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 221/432 (Batch 39.21)
# ================================================================================
# CONFIDENCE: medium (0.712)
# --------------------------------------------------------------------------------
# COMMENT:
# kalo yang seri PROMAX gimana bang?
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.712
#   Probabilities: Neg=0.211, Neu=0.712, Pos=0.077
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 222/432 (Batch 39.22)
# ================================================================================
# CONFIDENCE: medium (0.712)
# --------------------------------------------------------------------------------
# COMMENT:
# pixel 10 dong bang
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.712
#   Probabilities: Neg=0.210, Neu=0.712, Pos=0.078
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 223/432 (Batch 39.23)
# ================================================================================
# CONFIDENCE: medium (0.713)
# --------------------------------------------------------------------------------
# COMMENT:
# Bahas Xiaomi 17 pro bang
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.713
#   Probabilities: Neg=0.212, Neu=0.713, Pos=0.075
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 224/432 (Batch 39.24)
# ================================================================================
# CONFIDENCE: medium (0.713)
# --------------------------------------------------------------------------------
# COMMENT:
# 2 suhu di bidangnya masing2 kolaborasi, sesuai tagline om helmy, daging semua emang
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.713
#   Probabilities: Neg=0.209, Neu=0.713, Pos=0.078
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 225/432 (Batch 39.25)
# ================================================================================
# CONFIDENCE: medium (0.713)
# --------------------------------------------------------------------------------
# COMMENT:
# Lagi hits emang bang ijo sagne ??
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.713
#   Probabilities: Neg=0.188, Neu=0.713, Pos=0.099
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 226/432 (Batch 39.26)
# ================================================================================
# CONFIDENCE: medium (0.713)
# --------------------------------------------------------------------------------
# COMMENT:
# kyak nya helmi yahya, agak2 nggak  nyambung bicara nya om deddy.
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.713
#   Probabilities: Neg=0.100, Neu=0.713, Pos=0.186
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 227/432 (Batch 39.27)
# ================================================================================
# CONFIDENCE: medium (0.714)
# --------------------------------------------------------------------------------
# COMMENT:
# Ntn pake 15 pro
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.714
#   Probabilities: Neg=0.186, Neu=0.714, Pos=0.100
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 228/432 (Batch 39.28)
# ================================================================================
# CONFIDENCE: medium (0.714)
# --------------------------------------------------------------------------------
# COMMENT:
# Tidak ada chargernya... Tidak ada chargernya... Tidaaak ada chargernya ( suara om Deddy JAGAT REVIEW)??????
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.714
#   Probabilities: Neg=0.207, Neu=0.714, Pos=0.078
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice: 0
# ✓ Corrected from 1 to 0
#
# ================================================================================
# COMMENT 229/432 (Batch 39.29)
# ================================================================================
# CONFIDENCE: medium (0.714)
# --------------------------------------------------------------------------------
# COMMENT:
# Xiomi 17 pro bang
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.714
#   Probabilities: Neg=0.208, Neu=0.714, Pos=0.078
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 230/432 (Batch 39.30)
# ================================================================================
# CONFIDENCE: medium (0.714)
# --------------------------------------------------------------------------------
# COMMENT:
# Tablet astra magic kapan bang???
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.714
#   Probabilities: Neg=0.188, Neu=0.714, Pos=0.098
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 231/432 (Batch 39.31)
# ================================================================================
# CONFIDENCE: medium (0.715)
# --------------------------------------------------------------------------------
# COMMENT:
# Bang David, neks review  Xiaomi 17 pro klo dah rilis vs ipon 17 pro. Kayaknya seru perang teknologi nya
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.715
#   Probabilities: Neg=0.208, Neu=0.715, Pos=0.078
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 232/432 (Batch 39.32)
# ================================================================================
# CONFIDENCE: medium (0.715)
# --------------------------------------------------------------------------------
# COMMENT:
# Akhirnya OM Helmi Yahya, undang OM Dedy,udah lama pingin Muncul di Podcast ini ??
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.715
#   Probabilities: Neg=0.185, Neu=0.715, Pos=0.100
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 233/432 (Batch 39.33)
# ================================================================================
# CONFIDENCE: medium (0.716)
# --------------------------------------------------------------------------------
# COMMENT:
# Di tunggu riview xiaomi 17 pro nya bang
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.716
#   Probabilities: Neg=0.207, Neu=0.716, Pos=0.078
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 234/432 (Batch 39.34)
# ================================================================================
# CONFIDENCE: medium (0.716)
# --------------------------------------------------------------------------------
# COMMENT:
# Bang bahas Xiaomi 17 dong
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.716
#   Probabilities: Neg=0.208, Neu=0.716, Pos=0.076
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 235/432 (Batch 39.35)
# ================================================================================
# CONFIDENCE: medium (0.717)
# --------------------------------------------------------------------------------
# COMMENT:
# Mana kapal apinya bang david? padahal gua nungguin wkwk
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.717
#   Probabilities: Neg=0.181, Neu=0.717, Pos=0.102
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 236/432 (Batch 39.36)
# ================================================================================
# CONFIDENCE: medium (0.717)
# --------------------------------------------------------------------------------
# COMMENT:
# <a href="https://www.youtube.com/watch?v=9-poYwCZxDQ&amp;t=1181">19:41</a> orange vintage kata gw mah ??
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.717
#   Probabilities: Neg=0.185, Neu=0.717, Pos=0.098
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 237/432 (Batch 39.37)
# ================================================================================
# CONFIDENCE: medium (0.717)
# --------------------------------------------------------------------------------
# COMMENT:
# Bandingin bang sama xiaomi 17 pro ??
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.717
#   Probabilities: Neg=0.206, Neu=0.717, Pos=0.077
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 238/432 (Batch 39.38)
# ================================================================================
# CONFIDENCE: medium (0.717)
# --------------------------------------------------------------------------------
# COMMENT:
# next bahas laptop lenovo loq dong
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.717
#   Probabilities: Neg=0.205, Neu=0.717, Pos=0.078
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 239/432 (Batch 39.39)
# ================================================================================
# CONFIDENCE: medium (0.717)
# --------------------------------------------------------------------------------
# COMMENT:
# Kapan bahas fersi XIAOMI 17 PRO nya bang. penasaran pendapat abang.
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.717
#   Probabilities: Neg=0.206, Neu=0.717, Pos=0.076
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 240/432 (Batch 39.40)
# ================================================================================
# CONFIDENCE: medium (0.718)
# --------------------------------------------------------------------------------
# COMMENT:
# Bang saya mau upgrade iPhone lagi, ada dana untuk DP. 2 jt.. untuk angsuran nya 3 tahun berapa kira&quot;...
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.718
#   Probabilities: Neg=0.168, Neu=0.718, Pos=0.114
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 241/432 (Batch 39.41)
# ================================================================================
# CONFIDENCE: medium (0.718)
# --------------------------------------------------------------------------------
# COMMENT:
# Widih ngejreng bgt hp poconya bang David ??
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.718
#   Probabilities: Neg=0.191, Neu=0.718, Pos=0.091
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 242/432 (Batch 39.42)
# ================================================================================
# CONFIDENCE: medium (0.718)
# --------------------------------------------------------------------------------
# COMMENT:
# bang xiaomi 17 pro dong bang
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.718
#   Probabilities: Neg=0.204, Neu=0.718, Pos=0.078
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 243/432 (Batch 39.43)
# ================================================================================
# CONFIDENCE: medium (0.718)
# --------------------------------------------------------------------------------
# COMMENT:
# <a href="https://www.youtube.com/watch?v=9-poYwCZxDQ&amp;t=182">03:02</a> Ijo Rumah Sakit bang.. ?? soalnya RSUD di sini warna gitu ??
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.718
#   Probabilities: Neg=0.184, Neu=0.718, Pos=0.098
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 244/432 (Batch 39.44)
# ================================================================================
# CONFIDENCE: medium (0.718)
# --------------------------------------------------------------------------------
# COMMENT:
# Xiaomi 17 pro bang, review
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.718
#   Probabilities: Neg=0.205, Neu=0.718, Pos=0.077
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 245/432 (Batch 39.45)
# ================================================================================
# CONFIDENCE: medium (0.719)
# --------------------------------------------------------------------------------
# COMMENT:
# pake lipbalm banggg Allahuakbar wkwk
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.719
#   Probabilities: Neg=0.192, Neu=0.719, Pos=0.090
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 246/432 (Batch 39.46)
# ================================================================================
# CONFIDENCE: medium (0.719)
# --------------------------------------------------------------------------------
# COMMENT:
# Bang david info dong beli pixel di toko mana yang amanah
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.719
#   Probabilities: Neg=0.179, Neu=0.719, Pos=0.101
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 247/432 (Batch 39.47)
# ================================================================================
# CONFIDENCE: medium (0.719)
# --------------------------------------------------------------------------------
# COMMENT:
# Bang, review xiaomi 17 pro
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.719
#   Probabilities: Neg=0.204, Neu=0.719, Pos=0.077
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 248/432 (Batch 39.48)
# ================================================================================
# CONFIDENCE: medium (0.719)
# --------------------------------------------------------------------------------
# COMMENT:
# Ekosistem jika temen dan kita sendiri jg pake.... Btw, jika kita cm pake ip dan tdk pake yg lain serta kebanyakan temen tdk pake ip, ya ama jg bohong karena otomatis cm dipake wa dan foto2 doang
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.719
#   Probabilities: Neg=0.172, Neu=0.719, Pos=0.108
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 249/432 (Batch 39.49)
# ================================================================================
# CONFIDENCE: medium (0.720)
# --------------------------------------------------------------------------------
# COMMENT:
# Bang david tolong kasih rekomendasi laptop untuk jualan online ??
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.720
#   Probabilities: Neg=0.189, Neu=0.720, Pos=0.092
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 250/432 (Batch 39.50)
# ================================================================================
# CONFIDENCE: medium (0.720)
# --------------------------------------------------------------------------------
# COMMENT:
# 17 vs huwaei dong bang
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.720
#   Probabilities: Neg=0.202, Neu=0.720, Pos=0.079
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ✓ Batch 39 completed!
#   Verified in this batch: 50
#   Corrections in this batch: 1
#   Batch accuracy: 98.0%
#   Total verified: 250/432
#   Overall accuracy: 93.2%
#   Progress saved: 'verification_70percent_batch_39.csv'
#
# 182 comments remaining. Continue to next batch? (y/n): y
#
# ============================================================
# BATCH 40 - Comments 251 to 300
# Total target: 432 comments
# ============================================================
#
# ================================================================================
# COMMENT 251/432 (Batch 40.1)
# ================================================================================
# CONFIDENCE: medium (0.720)
# --------------------------------------------------------------------------------
# COMMENT:
# G ada test video nya ?
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.720
#   Probabilities: Neg=0.174, Neu=0.720, Pos=0.106
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 252/432 (Batch 40.2)
# ================================================================================
# CONFIDENCE: medium (0.720)
# --------------------------------------------------------------------------------
# COMMENT:
# Sebelum beli gadget.<br>kalo mau simple padat nonton david gadgetin<br>kalo mau sangat detail jagat review
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.720
#   Probabilities: Neg=0.179, Neu=0.720, Pos=0.101
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 253/432 (Batch 40.3)
# ================================================================================
# CONFIDENCE: medium (0.720)
# --------------------------------------------------------------------------------
# COMMENT:
# <a href="https://www.youtube.com/watch?v=9-poYwCZxDQ&amp;t=658">10:58</a> jujur gua akuin
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.720
#   Probabilities: Neg=0.182, Neu=0.720, Pos=0.098
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 254/432 (Batch 40.4)
# ================================================================================
# CONFIDENCE: medium (0.721)
# --------------------------------------------------------------------------------
# COMMENT:
# selalu klo liat review om Deddy  serasa lagi dikualihin HP. detail bgt tapi durasi lama, itu kelebihan sekaligus kekurangan tapi salah satu referensi.
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.721
#   Probabilities: Neg=0.161, Neu=0.721, Pos=0.117
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 255/432 (Batch 40.5)
# ================================================================================
# CONFIDENCE: medium (0.722)
# --------------------------------------------------------------------------------
# COMMENT:
# riview spark 40 pro bg
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.722
#   Probabilities: Neg=0.180, Neu=0.722, Pos=0.098
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 256/432 (Batch 40.6)
# ================================================================================
# CONFIDENCE: medium (0.723)
# --------------------------------------------------------------------------------
# COMMENT:
# review iphone air nya juga bang david??????
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.723
#   Probabilities: Neg=0.159, Neu=0.723, Pos=0.118
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 257/432 (Batch 40.7)
# ================================================================================
# CONFIDENCE: medium (0.723)
# --------------------------------------------------------------------------------
# COMMENT:
# Deddy Irvan Underrated Tech reviewer, favorite gw dr subscribernya msh 10rb
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.723
#   Probabilities: Neg=0.142, Neu=0.723, Pos=0.135
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 258/432 (Batch 40.8)
# ================================================================================
# CONFIDENCE: medium (0.723)
# --------------------------------------------------------------------------------
# COMMENT:
# Aku yang masih pake 7+??
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.723
#   Probabilities: Neg=0.145, Neu=0.723, Pos=0.132
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 259/432 (Batch 40.9)
# ================================================================================
# CONFIDENCE: medium (0.723)
# --------------------------------------------------------------------------------
# COMMENT:
# Silicon carbite pertama yg ngenalin honor om Ded..
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.723
#   Probabilities: Neg=0.187, Neu=0.723, Pos=0.090
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 260/432 (Batch 40.10)
# ================================================================================
# CONFIDENCE: medium (0.723)
# --------------------------------------------------------------------------------
# COMMENT:
# Bang David buat konten mystery box lagi bg
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.723
#   Probabilities: Neg=0.177, Neu=0.723, Pos=0.100
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 261/432 (Batch 40.11)
# ================================================================================
# CONFIDENCE: medium (0.724)
# --------------------------------------------------------------------------------
# COMMENT:
# di tunggu unboxing redmi 17 pro max nya. sekalian bandingin sama ip 17 pro max
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.724
#   Probabilities: Neg=0.165, Neu=0.724, Pos=0.112
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 262/432 (Batch 40.12)
# ================================================================================
# CONFIDENCE: medium (0.724)
# --------------------------------------------------------------------------------
# COMMENT:
# sry OOT.<br>bang, ane lagi cari karyawan pria/wanita max umur 55 taun buat di pabrik bapak ane di daerah leuwih gajah cimahi, posisi admin produksi gaji 6.5 juta/bulan.<br>terimakasih sebelumnya bang. Tuhan memberkati ????
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.724
#   Probabilities: Neg=0.186, Neu=0.724, Pos=0.090
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 263/432 (Batch 40.13)
# ================================================================================
# CONFIDENCE: medium (0.724)
# --------------------------------------------------------------------------------
# COMMENT:
# Adu sama X300 dan Xiaomi 17 bang ??
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.724
#   Probabilities: Neg=0.165, Neu=0.724, Pos=0.111
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 264/432 (Batch 40.14)
# ================================================================================
# CONFIDENCE: medium (0.724)
# --------------------------------------------------------------------------------
# COMMENT:
# Bang bahas barang aneh atau misteri box dong
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.724
#   Probabilities: Neg=0.186, Neu=0.724, Pos=0.089
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 265/432 (Batch 40.15)
# ================================================================================
# CONFIDENCE: medium (0.725)
# --------------------------------------------------------------------------------
# COMMENT:
# Next kita adukan dengan Xiaomi 17 bang David, jadi gak sabar nunggu next konten nya ??
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.725
#   Probabilities: Neg=0.179, Neu=0.725, Pos=0.097
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 266/432 (Batch 40.16)
# ================================================================================
# CONFIDENCE: medium (0.725)
# --------------------------------------------------------------------------------
# COMMENT:
# Apa sic special nya iphone?
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.725
#   Probabilities: Neg=0.134, Neu=0.725, Pos=0.141
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 267/432 (Batch 40.17)
# ================================================================================
# CONFIDENCE: medium (0.725)
# --------------------------------------------------------------------------------
# COMMENT:
# <a href="https://www.youtube.com/watch?v=9-poYwCZxDQ&amp;t=797">13:17</a> Xiaomi udh dari dlu. ??<br>Tapi icon pesawat pas flight mode detail kecil yg unik sih. Wkwk
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.725
#   Probabilities: Neg=0.129, Neu=0.725, Pos=0.146
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 268/432 (Batch 40.18)
# ================================================================================
# CONFIDENCE: medium (0.726)
# --------------------------------------------------------------------------------
# COMMENT:
# DI Ending expersi Bang David sangat sangat menjelaskan dan dari gesturnya sudah sangat sangat sangat sangat wow
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.726
#   Probabilities: Neg=0.149, Neu=0.726, Pos=0.126
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 269/432 (Batch 40.19)
# ================================================================================
# CONFIDENCE: medium (0.726)
# --------------------------------------------------------------------------------
# COMMENT:
# Bang bahasa Oppo k13 turbo
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.726
#   Probabilities: Neg=0.150, Neu=0.726, Pos=0.124
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 270/432 (Batch 40.20)
# ================================================================================
# CONFIDENCE: medium (0.726)
# --------------------------------------------------------------------------------
# COMMENT:
# Nah yang ditunggu tunggu
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.726
#   Probabilities: Neg=0.175, Neu=0.726, Pos=0.099
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 271/432 (Batch 40.21)
# ================================================================================
# CONFIDENCE: medium (0.726)
# --------------------------------------------------------------------------------
# COMMENT:
# next om undang GTID
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.726
#   Probabilities: Neg=0.174, Neu=0.726, Pos=0.099
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 272/432 (Batch 40.22)
# ================================================================================
# CONFIDENCE: medium (0.727)
# --------------------------------------------------------------------------------
# COMMENT:
# Ke 100
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.727
#   Probabilities: Neg=0.138, Neu=0.727, Pos=0.135
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# ...
#   Probabilities: Neg=0.079, Neu=0.762, Pos=0.159
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 415/432 (Batch 43.15)
# ================================================================================
# CONFIDENCE: medium (0.762)
# --------------------------------------------------------------------------------
# COMMENT:
# Bang Sony Xperia 10 VII kapan bang
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.762
#   Probabilities: Neg=0.102, Neu=0.762, Pos=0.136
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 416/432 (Batch 43.16)
# ================================================================================
# CONFIDENCE: medium (0.764)
# --------------------------------------------------------------------------------
# COMMENT:
# Next bahas HDC nya bang??
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.764
#   Probabilities: Neg=0.074, Neu=0.764, Pos=0.163
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 417/432 (Batch 43.17)
# ================================================================================
# CONFIDENCE: medium (0.764)
# --------------------------------------------------------------------------------
# COMMENT:
# Bang coba spilin samsung A17 5g
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.764
#   Probabilities: Neg=0.078, Neu=0.764, Pos=0.158
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 418/432 (Batch 43.18)
# ================================================================================
# CONFIDENCE: medium (0.764)
# --------------------------------------------------------------------------------
# COMMENT:
# bang coba review Samsung galaxy a17 5g????
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.764
#   Probabilities: Neg=0.076, Neu=0.764, Pos=0.160
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 419/432 (Batch 43.19)
# ================================================================================
# CONFIDENCE: medium (0.765)
# --------------------------------------------------------------------------------
# COMMENT:
# kalau mau landscape orangnya harus rame bang coba
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.765
#   Probabilities: Neg=0.076, Neu=0.765, Pos=0.159
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 420/432 (Batch 43.20)
# ================================================================================
# CONFIDENCE: medium (0.765)
# --------------------------------------------------------------------------------
# COMMENT:
# Minta hpnya satu aja bang terserh mrek apa
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.765
#   Probabilities: Neg=0.078, Neu=0.765, Pos=0.157
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 421/432 (Batch 43.21)
# ================================================================================
# CONFIDENCE: medium (0.765)
# --------------------------------------------------------------------------------
# COMMENT:
# bang coba review dong iphone 17 pro max
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.765
#   Probabilities: Neg=0.078, Neu=0.765, Pos=0.157
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 422/432 (Batch 43.22)
# ================================================================================
# CONFIDENCE: medium (0.766)
# --------------------------------------------------------------------------------
# COMMENT:
# bang review hotwav c16 pro
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.766
#   Probabilities: Neg=0.074, Neu=0.766, Pos=0.160
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 423/432 (Batch 43.23)
# ================================================================================
# CONFIDENCE: medium (0.766)
# --------------------------------------------------------------------------------
# COMMENT:
# bang review hotwav c16 pro
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.766
#   Probabilities: Neg=0.074, Neu=0.766, Pos=0.160
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 424/432 (Batch 43.24)
# ================================================================================
# CONFIDENCE: medium (0.766)
# --------------------------------------------------------------------------------
# COMMENT:
# bang review hotwav c16 pro
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.766
#   Probabilities: Neg=0.074, Neu=0.766, Pos=0.160
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 425/432 (Batch 43.25)
# ================================================================================
# CONFIDENCE: medium (0.766)
# --------------------------------------------------------------------------------
# COMMENT:
# Review pertama
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.766
#   Probabilities: Neg=0.076, Neu=0.766, Pos=0.158
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 426/432 (Batch 43.26)
# ================================================================================
# CONFIDENCE: medium (0.767)
# --------------------------------------------------------------------------------
# COMMENT:
# lol.jagat review ngmngya objective
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.767
#   Probabilities: Neg=0.076, Neu=0.767, Pos=0.157
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 427/432 (Batch 43.27)
# ================================================================================
# CONFIDENCE: medium (0.768)
# --------------------------------------------------------------------------------
# COMMENT:
# bang, review xiaomi pad mini
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.768
#   Probabilities: Neg=0.078, Neu=0.768, Pos=0.154
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 428/432 (Batch 43.28)
# ================================================================================
# CONFIDENCE: medium (0.768)
# --------------------------------------------------------------------------------
# COMMENT:
# Bang Xioami 17 bang
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.768
#   Probabilities: Neg=0.075, Neu=0.768, Pos=0.157
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 429/432 (Batch 43.29)
# ================================================================================
# CONFIDENCE: medium (0.768)
# --------------------------------------------------------------------------------
# COMMENT:
# coba review realme 15 5G bang
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.768
#   Probabilities: Neg=0.076, Neu=0.768, Pos=0.156
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 430/432 (Batch 43.30)
# ================================================================================
# CONFIDENCE: medium (0.768)
# --------------------------------------------------------------------------------
# COMMENT:
# bahas samsung a17 bang????
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.768
#   Probabilities: Neg=0.075, Neu=0.768, Pos=0.156
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 431/432 (Batch 43.31)
# ================================================================================
# CONFIDENCE: medium (0.769)
# --------------------------------------------------------------------------------
# COMMENT:
# Hadir bang
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.769
#   Probabilities: Neg=0.075, Neu=0.769, Pos=0.156
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ================================================================================
# COMMENT 432/432 (Batch 43.32)
# ================================================================================
# CONFIDENCE: medium (0.771)
# --------------------------------------------------------------------------------
# COMMENT:
# Ngk review Poco f9 bang?
# --------------------------------------------------------------------------------
# MODEL PREDICTION:
#   Label: 1 (Neutral)
#   Confidence: 0.771
#   Probabilities: Neg=0.076, Neu=0.771, Pos=0.153
# --------------------------------------------------------------------------------
# VERIFICATION OPTIONS:
# 0: Negative
# 1: Neutral
# 2: Positive
# Enter: Accept model prediction
# s: Skip this comment
# ================================================================================
# Enter your choice:
# ✓ Accepted model prediction
#
# ✓ Batch 43 completed!
#   Verified in this batch: 32
#   Corrections in this batch: 0
#   Batch accuracy: 100.0%
#   Total verified: 432/432
#   Overall accuracy: 95.6%
#   Progress saved: 'verification_70percent_batch_43.csv'
#
# ✓ Target of 432 comments reached!
#
#  VERIFICATION COMPLETED!
# Total verified: 432/432
# Total corrections: 19
# Final model accuracy: 95.6%

# %%
# Block 5: Combine with Original Data and Update Model
def combine_and_update_model(original_labeled_df, verified_70percent_df):
    """
    Combine original 30% labeled data with newly verified 70% data
    and retrain the model
    """
    print("Combining original 30% data with verified 70% data...")

    # Prepare original labeled data
    original_clean = original_labeled_df[['video_id', 'author', 'comment', 'label']].copy()
    original_clean['label_source'] = 'manual_initial_30percent'

    # Prepare newly verified 70% data
    verified_clean = verified_70percent_df[verified_70percent_df['verified'] == True]
    verified_clean = verified_clean[['video_id', 'author', 'comment', 'human_label']].copy()
    verified_clean = verified_clean.rename(columns={'human_label': 'label'})
    verified_clean['label_source'] = 'manual_verified_done'

    # Combine datasets
    combined_100percent_df = pd.concat([original_clean, verified_clean], ignore_index=True)

    print(f"Combined dataset created:")
    print(f"  Original manual labels (30%): {len(original_clean)}")
    print(f"  Newly verified labels (70%): {len(verified_clean)}")
    print(f"  Total: {len(combined_100percent_df)} comments")
    print(f"  Coverage: {len(combined_100percent_df)/4418*100:.1f}% of total data")

    # Analyze the combined dataset
    print(f"\nCOMBINED DATASET ANALYSIS:")
    print("=" * 40)

    # Label distribution
    label_dist = combined_100percent_df['label'].value_counts().sort_index()
    print("Label Distribution:")
    for label, count in label_dist.items():
        sentiment = get_sentiment_name(label)
        percentage = count / len(combined_100percent_df) * 100
        print(f"  {sentiment}: {count} ({percentage:.1f}%)")

    # Source distribution
    source_dist = combined_100percent_df['label_source'].value_counts()
    print(f"\nLabel Sources:")
    for source, count in source_dist.items():
        percentage = count / len(combined_100percent_df) * 100
        print(f"  {source}: {count} ({percentage:.1f}%)")

    # Save combined dataset
    combined_100percent_df.to_csv('combined_labeled_data.csv', index=False)
    print(f"\nCombined dataset saved as 'combined_labeled_data.csv'")

    # Retrain model on combined data
    print("\nRetraining model on 100% labeled data...")
    model_updated, vectorizer_updated = retrain_model_on_combined_data(combined_100percent_df)

    return combined_100percent_df, model_updated, vectorizer_updated

def retrain_model_on_combined_data(combined_df):
    """
    Retrain the model on the combined 100% labeled data
    """
    # Prepare features and labels
    X_combined = combined_df['comment'].fillna('')
    y_combined = combined_df['label']

    # Create new vectorizer with expanded vocabulary
    vectorizer_updated = TfidfVectorizer(
        max_features=4000,  # Increased features for larger dataset
        ngram_range=(1, 2),
        min_df=2,
        max_df=0.95,
        stop_words=None
    )

    X_combined_vec = vectorizer_updated.fit_transform(X_combined)

    # Train SVM on larger dataset
    base_svm_updated = SVC(
        kernel='linear',
        probability=False,
        random_state=42,
        class_weight='balanced'
    )

    model_updated = CalibratedClassifierCV(
        base_svm_updated,
        method='sigmoid',
        cv=min(5, len(combined_df))
    )

    model_updated.fit(X_combined_vec, y_combined)

    print("✓ Model retrained on 100% combined data!")
    print(f"Training data size: {len(combined_df)} comments")

    # Evaluate on training data
    train_predictions = model_updated.predict(X_combined_vec)
    train_accuracy = (train_predictions == y_combined).mean()

    print(f"Training accuracy: {train_accuracy:.3f}")
    print("\nClassification Report:")
    print(classification_report(y_combined, train_predictions))

    return model_updated, vectorizer_updated

# Combine and update model
verified_df = pd.read_csv('manual_verification_done.csv')
combined_df, model_updated, vectorizer_updated = combine_and_update_model(labeled_df, verified_df)
# Out:
# Combining original 30% data with verified 70% data...
# Combined dataset created:
#   Original manual labels (30%): 1092
#   Newly verified labels (70%): 2132
#   Total: 3224 comments
#   Coverage: 73.0% of total data
#
# COMBINED DATASET ANALYSIS:
# ========================================
# Label Distribution:
#   Negative: 1148 (35.6%)
#   Neutral: 1735 (53.8%)
#   Positive: 341 (10.6%)
#
# Label Sources:
#   manual_verified_done: 2132 (66.1%)
#   manual_initial_30percent: 1092 (33.9%)
#
# Combined dataset saved as 'combined_labeled_data.csv'
#
# Retraining model on 100% labeled data...
# ✓ Model retrained on 100% combined data!
# Training data size: 3224 comments
# Training accuracy: 0.908
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.92      0.91      1148
#            1       0.92      0.92      0.92      1735
#            2       0.90      0.78      0.84       341
#
#     accuracy                           0.91      3224
#    macro avg       0.90      0.88      0.89      3224
# weighted avg       0.91      0.91      0.91      3224

# %%
# Block 6: Prepare 30% Pseudo-Labeling Set
def prepare_pseudo_labeling_set(pseudo_set, model_updated, vectorizer_updated):
    print("Preparing pseudo-labeling set...")
    print(f"Pseudo-labeling set size: {len(pseudo_set)} comments")

    # Apply the updated model to the pseudo-labeling set
    X_pseudo = pseudo_set['comment'].fillna('')
    X_pseudo_vec = vectorizer_updated.transform(X_pseudo)

    predictions = model_updated.predict(X_pseudo_vec)
    probabilities = model_updated.predict_proba(X_pseudo_vec)
    max_probs = np.max(probabilities, axis=1)

    # Add predictions to pseudo set
    pseudo_labeled_set = pseudo_set.copy()
    pseudo_labeled_set['model_label'] = predictions
    pseudo_labeled_set['model_confidence'] = max_probs
    pseudo_labeled_set['prob_negative'] = probabilities[:, 0]
    pseudo_labeled_set['prob_neutral'] = probabilities[:, 1]
    pseudo_labeled_set['prob_positive'] = probabilities[:, 2]

    # Categorize by confidence
    pseudo_labeled_set['confidence_level'] = pd.cut(
        max_probs,
        bins=[0, 0.6, 0.8, 0.9, 1.0],
        labels=['low', 'medium', 'high', 'very_high'],
        right=False
    )

    print(f"\nPseudo-labeling set statistics:")
    print(f"Total comments: {len(pseudo_labeled_set)}")

    print("\nConfidence Distribution:")
    conf_counts = pseudo_labeled_set['confidence_level'].value_counts()
    for level, count in conf_counts.items():
        percentage = count / len(pseudo_labeled_set) * 100
        print(f"  {level}: {count} comments ({percentage:.1f}%)")

    print("\nPredicted Label Distribution:")
    label_counts = pseudo_labeled_set['model_label'].value_counts().sort_index()
    for label, count in label_counts.items():
        sentiment = get_sentiment_name(label)
        percentage = count / len(pseudo_labeled_set) * 100
        print(f"  {sentiment}: {count} comments ({percentage:.1f}%)")

    # Save pseudo-labeling set
    pseudo_labeled_set.to_csv('pseudo_labeled.csv', index=False)
    print(f"\n✓ Pseudo-labeling set saved as 'pseudo_labeled.csv'")

    return pseudo_labeled_set

# Prepare pseudo-labeling set
pseudo_labeled = prepare_pseudo_labeling_set(pseudo_set, model_updated, vectorizer_updated)
# Out:
# Preparing pseudo-labeling set...
# Pseudo-labeling set size: 915 comments
#
# Pseudo-labeling set statistics:
# Total comments: 915
#
# Confidence Distribution:
#   medium: 667 comments (72.9%)
#   low: 206 comments (22.5%)
#   high: 42 comments (4.6%)
#   very_high: 0 comments (0.0%)
#
# Predicted Label Distribution:
#   Negative: 393 comments (43.0%)
#   Neutral: 459 comments (50.2%)
#   Positive: 63 comments (6.9%)
#
# ✓ Pseudo-labeling set saved as 'pseudo_labeling.csv'

# %%
pseudo_for_combination = pseudo_labeled[['video_id', 'author', 'comment', 'model_label']].copy()
pseudo_for_combination = pseudo_for_combination.rename(columns={'model_label': 'label'})
pseudo_for_combination['label_source'] = 'pseudo_labeled'

final_dataset = pd.concat([combined_df, pseudo_for_combination], ignore_index=True)
print(f"COMBINATION RESULTS:")
print(f"   - Verified labeled data: {len(combined_df)} comments")
print(f"   - High-confidence pseudo-labels: {len(pseudo_labeled)} comments")
print(f"   - Combined dataset: {len(final_dataset)} comments")
print(f"Final dataset saved as 'final_labeled_dataset.csv")
final_dataset.to_csv('final_labeled_dataset.csv', index=False)
# Out:
# COMBINATION RESULTS:
#    - Verified labeled data: 3224 comments
#    - High-confidence pseudo-labels: 915 comments
#    - Combined dataset: 4139 comments
# Final dataset saved as 'final_labeled_dataset.csv
